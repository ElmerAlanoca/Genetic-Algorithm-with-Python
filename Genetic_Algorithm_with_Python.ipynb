# %% [markdown]
# <a href="https://colab.research.google.com/github/ElmerAlanoca/Genetic-Algorithm-with-Python/blob/main/Genetic_Algorithm_with_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Genetic Algorithm with Python

# %% [markdown]
# The Genetic Algorithm is a class of evolutionary algorithm that is broadly inspired by biological evolution. We all know evolution, it is a selection of parents, reproduction, and mutation of offsprings. The main aim of evolution is to reproduce offsprings that are biologically better than their parents. Genetic algorithm is mainly based on natural selection and it tries to simulate the theory of evolution.

# %%
import numpy as np
import matplotlib.pyplot as plt
import copy

# %%
# cost function
def sphere(x):
  ''' This is the problem we will be
  optimizing, each chromosome of parent has a cost
  which is calculated from this cost function'''
  
  return sum(x**2)

# %%
def roulette_wheel_selection(p):
  ''' Roulette Wheel Selection is a method of parent 
  selection for breeding. We take the cummulative sum of probabilities
  and select the first parent whose cummulative sum is greater than
  random number'''

  c = np.cumsum(p)
  r = sum(p) * np.random.rand()
  ind = np.argwhere(r <= c)
  
  return ind[0][0]

# %%
def crossover(p1, p2):
  ''' Performing uniform crossover. Alpha is the flag
  that determines which gene of each chromosome is choosen
  to be inherited by the offspring. Maultiply the alpha value
  with each gene of every chromosome of both the parents and
  then add the resultant value to get child chromosome'''
  
  c1 = copy.deepcopy(p1)
  c2 = copy.deepcopy(p2)

  # Uniform crossover
  alpha = np.random.uniform(0, 1, *(c1['position'].shape))
  c1['position'] = alpha*p1['position'] + (1-alpha)*p2['position']
  c2['position'] = alpha*p2['position'] + (1-alpha)*p1['position']

  return c1, c2

# %%
def mutate(c, mu, sigma):
  '''
  c: child chromosome 
  mu: mutation rate. % of gene to be modified
  sigma: step size of mutation'''

  y = copy.deepcopy(c)
  flag = np.random.rand(*(c['position'].shape)) <= mu  # array of True and Flase, indicating at which position to perform mutation
  ind = np.argwhere(flag)
  y['position'][ind] += sigma * np.random.randn(*ind.shape)
  
  return y

# %%
def bounds(c, varmin, varmax):
  ''' Defines the upper and lower bound of gene value'''
  
  c['position'] = np.maximum(c['position'], varmin)
  c['position'] = np.minimum(c['position'], varmax)

# %%
def sort(arr):
  ''' Bubble sorting the population + offsoring
  in every iteration to get best fit individuals at top'''
  
  n = len(arr) 
  
  for i in range(n-1): 
  
    for j in range(0, n-i-1):  
            if arr[j]['cost'] > arr[j+1]['cost'] : 
                arr[j], arr[j+1] = arr[j+1], arr[j]
    return arr

# %%
def ga(costfunc, num_var, varmin, varmax, maxit, npop, num_children, mu, sigma, beta):
  
  # Placeholder for each individual
  population = {}
  for i in range(npop):                                                         # each inidivdual has position(chromosomes) and cost,
    population[i] = {'position': None, 'cost': None}                            # create individual as many as population size(npop)

  # Best solution found
  bestsol = copy.deepcopy(population)
  bestsol_cost = np.inf                                                         # initial best cost is infinity

  # Initialize population - 1st Gen
  for i in range(npop):
      population[i]['position'] = np.random.uniform(varmin, varmax, num_var)    # randomly initialize the chromosomes and cost
      population[i]['cost'] = costfunc(population[i]['position'])

      if population[i]['cost'] < bestsol_cost:                                  # if cost of an individual is less(best) than best cost,
        bestsol = copy.deepcopy(population[i])                                  # replace the best solution with that individual

  # Best cost of each generation/iteration
  bestcost = np.empty(maxit)

  # Main loop
  for it in range(maxit):

    # Calculating probability for roulette wheel selection
    costs = []
    for i in range(len(population)):
      costs.append(population[i]['cost'])                                       # list of all the population cost
    costs = np.array(costs)
    avg_cost = np.mean(costs)                                                   # taking average of the costs 
    if avg_cost != 0:
      costs = costs/avg_cost
    probs = np.exp(-beta*costs)                                                 # probability is exponensial of -ve beta times costs

    for _ in range(num_children//2):                                            # we will be having two off springs for each crossover 
                                                                                # hence divide number of children by 2
      '''   
      -> choosing two parents randomly for mating
      -> we are shuffling all the 20 parent individuals and
      -> choosing first two of the shuffled array as our parents for mating 
      
      Randomly selecting parents by shiffling them.
      But we will be using roulette wheel slection 
      for our algorithm

      q = np.random.permutation(npop)
      p1 = population[q[0]]
      p2 = population[q[1]]
      '''

      # Roulette wheel selection
      p1 = population[roulette_wheel_selection(probs)]
      p2 = population[roulette_wheel_selection(probs)]

      # crossover two parents
      c1, c2 = crossover(p1, p2)
          
      # Perform mutation
      c1 = mutate(c1, mu, sigma)
      c2 = mutate(c2, mu, sigma)
      
      # Apply bounds
      bounds(c1, varmin, varmax)
      bounds(c2, varmin, varmax)
      
      # Evaluate first off spring
      c1['cost'] = costfunc(c1['position'])                                     # calculate cost function of child 1
      
      if type(bestsol_cost) == float:
        if c1['cost'] < bestsol_cost:                                           # replacing best solution in every generation/iteration
          bestsol_cost = copy.deepcopy(c1)
      else:
        if c1['cost'] < bestsol_cost['cost']:                                   # replacing best solution in every generation/iteration
          bestsol_cost = copy.deepcopy(c1)

      
      # Evaluate second off spring
      if c2['cost'] < bestsol_cost['cost']:                                     # replacing best solution in every generation/iteration
        bestsol_cost = copy.deepcopy(c2)
    
    # Merge, Sort and Select
    population[len(population)] = c1
    population[len(population)] = c2

    population = sort(population)

    # Store best cost
    bestcost[it] = bestsol_cost['cost']

    # Show generation information
    print('Iteration {}: Best Cost = {}'. format(it, bestcost[it]))


  out = population
  Bestsol = bestsol
  bestcost = bestcost
  return (out, Bestsol, bestcost)

# %%
# Problem definition
costfunc = sphere
num_var = 5       # number of decicion variables
varmin = -10      # lower bound
varmax = 10       # upper bound

# GA Parameters
maxit = 501                                              # number of iterations
npop = 20                                                # initial population size
beta = 1
prop_children = 1                                        # proportion of children to population
num_children = int(np.round(prop_children * npop/2)*2)   # making sure it always an even number
mu = 0.2                                                 # mutation rate 20%, 205 of 5 is 1, mutating 1 gene
sigma = 0.1                                              # step size of mutation


# Run GA
out = ga(costfunc, num_var, varmin, varmax, maxit, npop, num_children, mu, sigma, beta)

# Results
#(out, Bestsol, bestcost)
plt.plot(out[2])
plt.xlim(0, maxit)
plt.xlabel('Generations')
plt.ylabel('Best Cost')
plt.title('Genetic Algorithm')
plt.grid(True)
plt.show
# Out:
# Iteration 0: Best Cost = 29.98048437066859
# Iteration 1: Best Cost = 29.98048437066859
# Iteration 2: Best Cost = 29.0674350899644
# Iteration 3: Best Cost = 15.025518135068431
# Iteration 4: Best Cost = 15.025518135068431
# Iteration 5: Best Cost = 15.025518135068431
# Iteration 6: Best Cost = 15.025518135068431
# Iteration 7: Best Cost = 15.025518135068431
# Iteration 8: Best Cost = 15.025518135068431
# Iteration 9: Best Cost = 15.025518135068431
# Iteration 10: Best Cost = 15.025518135068431
# Iteration 11: Best Cost = 15.025518135068431
# Iteration 12: Best Cost = 15.025518135068431
# Iteration 13: Best Cost = 15.025518135068431
# Iteration 14: Best Cost = 15.025518135068431
# Iteration 15: Best Cost = 15.025518135068431
# Iteration 16: Best Cost = 15.025518135068431
# Iteration 17: Best Cost = 11.2307599488391
# Iteration 18: Best Cost = 11.2307599488391
# Iteration 19: Best Cost = 11.049318061897415
# Iteration 20: Best Cost = 11.049318061897415
# Iteration 21: Best Cost = 11.049318061897415
# Iteration 22: Best Cost = 11.049318061897415
# Iteration 23: Best Cost = 9.810076701115083
# Iteration 24: Best Cost = 8.39919253884027
# Iteration 25: Best Cost = 8.39919253884027
# Iteration 26: Best Cost = 8.39919253884027
# Iteration 27: Best Cost = 8.317506458433474
# Iteration 28: Best Cost = 7.9976528695897855
# Iteration 29: Best Cost = 7.9976528695897855
# Iteration 30: Best Cost = 6.885314006024711
# Iteration 31: Best Cost = 5.692229370519937
# Iteration 32: Best Cost = 5.692229370519937
# Iteration 33: Best Cost = 5.692229370519937
# Iteration 34: Best Cost = 4.086572038791028
# Iteration 35: Best Cost = 4.086572038791028
# Iteration 36: Best Cost = 4.086572038791028
# Iteration 37: Best Cost = 4.086572038791028
# Iteration 38: Best Cost = 4.086572038791028
# Iteration 39: Best Cost = 4.086572038791028
# Iteration 40: Best Cost = 4.086572038791028
# Iteration 41: Best Cost = 4.086572038791028
# Iteration 42: Best Cost = 4.086572038791028
# Iteration 43: Best Cost = 4.086572038791028
# Iteration 44: Best Cost = 4.086572038791028
# Iteration 45: Best Cost = 4.086572038791028
# Iteration 46: Best Cost = 4.086572038791028
# Iteration 47: Best Cost = 4.086572038791028
# Iteration 48: Best Cost = 2.666663457006734
# Iteration 49: Best Cost = 2.666663457006734
# Iteration 50: Best Cost = 2.666663457006734
# Iteration 51: Best Cost = 2.666663457006734
# Iteration 52: Best Cost = 2.666663457006734
# Iteration 53: Best Cost = 2.666663457006734
# Iteration 54: Best Cost = 2.666663457006734
# Iteration 55: Best Cost = 2.666663457006734
# Iteration 56: Best Cost = 2.666663457006734
# Iteration 57: Best Cost = 2.666663457006734
# Iteration 58: Best Cost = 2.666663457006734
# Iteration 59: Best Cost = 2.666663457006734
# Iteration 60: Best Cost = 2.666663457006734
# Iteration 61: Best Cost = 2.666663457006734
# Iteration 62: Best Cost = 2.666663457006734
# Iteration 63: Best Cost = 2.666663457006734
# Iteration 64: Best Cost = 2.666663457006734
# Iteration 65: Best Cost = 2.666663457006734
# Iteration 66: Best Cost = 2.666663457006734
# Iteration 67: Best Cost = 2.666663457006734
# Iteration 68: Best Cost = 2.666663457006734
# Iteration 69: Best Cost = 2.666663457006734
# Iteration 70: Best Cost = 2.666663457006734
# Iteration 71: Best Cost = 2.666663457006734
# Iteration 72: Best Cost = 2.666663457006734
# Iteration 73: Best Cost = 2.666663457006734
# Iteration 74: Best Cost = 2.666663457006734
# Iteration 75: Best Cost = 2.666663457006734
# Iteration 76: Best Cost = 2.666663457006734
# Iteration 77: Best Cost = 2.666663457006734
# Iteration 78: Best Cost = 2.666663457006734
# Iteration 79: Best Cost = 2.666663457006734
# Iteration 80: Best Cost = 2.666663457006734
# Iteration 81: Best Cost = 2.666663457006734
# Iteration 82: Best Cost = 2.666663457006734
# Iteration 83: Best Cost = 2.666663457006734
# Iteration 84: Best Cost = 2.666663457006734
# Iteration 85: Best Cost = 2.666663457006734
# Iteration 86: Best Cost = 2.666663457006734
# Iteration 87: Best Cost = 2.666663457006734
# Iteration 88: Best Cost = 2.666663457006734
# Iteration 89: Best Cost = 2.666663457006734
# Iteration 90: Best Cost = 2.666663457006734
# Iteration 91: Best Cost = 2.666663457006734
# Iteration 92: Best Cost = 2.666663457006734
# Iteration 93: Best Cost = 2.666663457006734
# Iteration 94: Best Cost = 2.666663457006734
# Iteration 95: Best Cost = 2.666663457006734
# Iteration 96: Best Cost = 2.666663457006734
# Iteration 97: Best Cost = 2.666663457006734
# Iteration 98: Best Cost = 2.666663457006734
# Iteration 99: Best Cost = 2.666663457006734
# Iteration 100: Best Cost = 2.666663457006734
# Iteration 101: Best Cost = 2.666663457006734
# Iteration 102: Best Cost = 2.666663457006734
# Iteration 103: Best Cost = 2.666663457006734
# Iteration 104: Best Cost = 2.666663457006734
# Iteration 105: Best Cost = 2.666663457006734
# Iteration 106: Best Cost = 2.666663457006734
# Iteration 107: Best Cost = 2.666663457006734
# Iteration 108: Best Cost = 2.666663457006734
# Iteration 109: Best Cost = 2.666663457006734
# Iteration 110: Best Cost = 2.666663457006734
# Iteration 111: Best Cost = 2.666663457006734
# Iteration 112: Best Cost = 2.666663457006734
# Iteration 113: Best Cost = 2.666663457006734
# Iteration 114: Best Cost = 1.6681110525226637
# Iteration 115: Best Cost = 1.6681110525226637
# Iteration 116: Best Cost = 1.6681110525226637
# Iteration 117: Best Cost = 1.6681110525226637
# Iteration 118: Best Cost = 1.6681110525226637
# Iteration 119: Best Cost = 1.6681110525226637
# Iteration 120: Best Cost = 1.6681110525226637
# Iteration 121: Best Cost = 1.6681110525226637
# Iteration 122: Best Cost = 1.6681110525226637
# Iteration 123: Best Cost = 1.6681110525226637
# Iteration 124: Best Cost = 1.6681110525226637
# Iteration 125: Best Cost = 1.6681110525226637
# Iteration 126: Best Cost = 1.6681110525226637
# Iteration 127: Best Cost = 1.6681110525226637
# Iteration 128: Best Cost = 1.6681110525226637
# Iteration 129: Best Cost = 1.6681110525226637
# Iteration 130: Best Cost = 1.6681110525226637
# Iteration 131: Best Cost = 1.6681110525226637
# Iteration 132: Best Cost = 1.6681110525226637
# Iteration 133: Best Cost = 1.6681110525226637
# Iteration 134: Best Cost = 1.6681110525226637
# Iteration 135: Best Cost = 1.6681110525226637
# Iteration 136: Best Cost = 1.6681110525226637
# Iteration 137: Best Cost = 1.6681110525226637
# Iteration 138: Best Cost = 1.6681110525226637
# Iteration 139: Best Cost = 1.6681110525226637
# Iteration 140: Best Cost = 1.6681110525226637
# Iteration 141: Best Cost = 1.6681110525226637
# Iteration 142: Best Cost = 1.6681110525226637
# Iteration 143: Best Cost = 1.6681110525226637
# Iteration 144: Best Cost = 1.6681110525226637
# Iteration 145: Best Cost = 1.6681110525226637
# Iteration 146: Best Cost = 1.6681110525226637
# Iteration 147: Best Cost = 1.6681110525226637
# Iteration 148: Best Cost = 1.6681110525226637
# Iteration 149: Best Cost = 1.6681110525226637
# Iteration 150: Best Cost = 1.6681110525226637
# Iteration 151: Best Cost = 1.6681110525226637
# Iteration 152: Best Cost = 1.6681110525226637
# Iteration 153: Best Cost = 1.6681110525226637
# Iteration 154: Best Cost = 1.6681110525226637
# Iteration 155: Best Cost = 1.6681110525226637
# Iteration 156: Best Cost = 1.6681110525226637
# Iteration 157: Best Cost = 1.6681110525226637
# Iteration 158: Best Cost = 1.6681110525226637
# Iteration 159: Best Cost = 1.6681110525226637
# Iteration 160: Best Cost = 1.6681110525226637
# Iteration 161: Best Cost = 1.6681110525226637
# Iteration 162: Best Cost = 1.6681110525226637
# Iteration 163: Best Cost = 1.6681110525226637
# Iteration 164: Best Cost = 1.6681110525226637
# Iteration 165: Best Cost = 1.6681110525226637
# Iteration 166: Best Cost = 1.6681110525226637
# Iteration 167: Best Cost = 1.6681110525226637
# Iteration 168: Best Cost = 1.6681110525226637
# Iteration 169: Best Cost = 1.6681110525226637
# Iteration 170: Best Cost = 1.6681110525226637
# Iteration 171: Best Cost = 1.6681110525226637
# Iteration 172: Best Cost = 1.6681110525226637
# Iteration 173: Best Cost = 1.6681110525226637
# Iteration 174: Best Cost = 1.6681110525226637
# Iteration 175: Best Cost = 1.6681110525226637
# Iteration 176: Best Cost = 1.6681110525226637
# Iteration 177: Best Cost = 1.6681110525226637
# Iteration 178: Best Cost = 1.6681110525226637
# Iteration 179: Best Cost = 1.6681110525226637
# Iteration 180: Best Cost = 1.6681110525226637
# Iteration 181: Best Cost = 1.6681110525226637
# Iteration 182: Best Cost = 1.6681110525226637
# Iteration 183: Best Cost = 1.6681110525226637
# Iteration 184: Best Cost = 1.6681110525226637
# Iteration 185: Best Cost = 1.6681110525226637
# Iteration 186: Best Cost = 1.6681110525226637
# Iteration 187: Best Cost = 1.6681110525226637
# Iteration 188: Best Cost = 1.6681110525226637
# Iteration 189: Best Cost = 1.6681110525226637
# Iteration 190: Best Cost = 1.6681110525226637
# Iteration 191: Best Cost = 1.6681110525226637
# Iteration 192: Best Cost = 1.6681110525226637
# Iteration 193: Best Cost = 1.6681110525226637
# Iteration 194: Best Cost = 1.6681110525226637
# Iteration 195: Best Cost = 1.6681110525226637
# Iteration 196: Best Cost = 1.6681110525226637
# Iteration 197: Best Cost = 1.6681110525226637
# Iteration 198: Best Cost = 1.6681110525226637
# Iteration 199: Best Cost = 1.6681110525226637
# Iteration 200: Best Cost = 1.6681110525226637
# Iteration 201: Best Cost = 1.6681110525226637
# Iteration 202: Best Cost = 1.6681110525226637
# Iteration 203: Best Cost = 1.6681110525226637
# Iteration 204: Best Cost = 1.6681110525226637
# Iteration 205: Best Cost = 1.6681110525226637
# Iteration 206: Best Cost = 1.6681110525226637
# Iteration 207: Best Cost = 1.6681110525226637
# Iteration 208: Best Cost = 1.6681110525226637
# Iteration 209: Best Cost = 1.6681110525226637
# Iteration 210: Best Cost = 1.6681110525226637
# Iteration 211: Best Cost = 1.6681110525226637
# Iteration 212: Best Cost = 1.6681110525226637
# Iteration 213: Best Cost = 1.6681110525226637
# Iteration 214: Best Cost = 1.6681110525226637
# Iteration 215: Best Cost = 1.6681110525226637
# Iteration 216: Best Cost = 1.6681110525226637
# Iteration 217: Best Cost = 1.6681110525226637
# Iteration 218: Best Cost = 1.6681110525226637
# Iteration 219: Best Cost = 1.6681110525226637
# Iteration 220: Best Cost = 1.6681110525226637
# Iteration 221: Best Cost = 1.6681110525226637
# Iteration 222: Best Cost = 1.6681110525226637
# Iteration 223: Best Cost = 1.6681110525226637
# Iteration 224: Best Cost = 1.6681110525226637
# Iteration 225: Best Cost = 1.6681110525226637
# Iteration 226: Best Cost = 1.6681110525226637
# Iteration 227: Best Cost = 1.6681110525226637
# Iteration 228: Best Cost = 1.6681110525226637
# Iteration 229: Best Cost = 1.6681110525226637
# Iteration 230: Best Cost = 1.6681110525226637
# Iteration 231: Best Cost = 1.6681110525226637
# Iteration 232: Best Cost = 1.6681110525226637
# Iteration 233: Best Cost = 1.6681110525226637
# Iteration 234: Best Cost = 1.6681110525226637
# Iteration 235: Best Cost = 1.6681110525226637
# Iteration 236: Best Cost = 1.6681110525226637
# Iteration 237: Best Cost = 1.6681110525226637
# Iteration 238: Best Cost = 1.6681110525226637
# Iteration 239: Best Cost = 1.6681110525226637
# Iteration 240: Best Cost = 1.6681110525226637
# Iteration 241: Best Cost = 1.6681110525226637
# Iteration 242: Best Cost = 1.6681110525226637
# Iteration 243: Best Cost = 1.6681110525226637
# Iteration 244: Best Cost = 1.6681110525226637
# Iteration 245: Best Cost = 1.6681110525226637
# Iteration 246: Best Cost = 1.6681110525226637
# Iteration 247: Best Cost = 1.6681110525226637
# Iteration 248: Best Cost = 1.6681110525226637
# Iteration 249: Best Cost = 1.6681110525226637
# Iteration 250: Best Cost = 1.6681110525226637
# Iteration 251: Best Cost = 1.6681110525226637
# Iteration 252: Best Cost = 1.6681110525226637
# Iteration 253: Best Cost = 1.6681110525226637
# Iteration 254: Best Cost = 1.6681110525226637
# Iteration 255: Best Cost = 1.6681110525226637
# Iteration 256: Best Cost = 1.6681110525226637
# Iteration 257: Best Cost = 1.6681110525226637
# Iteration 258: Best Cost = 1.6681110525226637
# Iteration 259: Best Cost = 1.6681110525226637
# Iteration 260: Best Cost = 1.6681110525226637
# Iteration 261: Best Cost = 1.6681110525226637
# Iteration 262: Best Cost = 1.6681110525226637
# Iteration 263: Best Cost = 1.6681110525226637
# Iteration 264: Best Cost = 1.6681110525226637
# Iteration 265: Best Cost = 1.6681110525226637
# Iteration 266: Best Cost = 1.6681110525226637
# Iteration 267: Best Cost = 1.6681110525226637
# Iteration 268: Best Cost = 1.6681110525226637
# Iteration 269: Best Cost = 1.6681110525226637
# Iteration 270: Best Cost = 1.6681110525226637
# Iteration 271: Best Cost = 1.6681110525226637
# Iteration 272: Best Cost = 1.6681110525226637
# Iteration 273: Best Cost = 1.6681110525226637
# Iteration 274: Best Cost = 1.6681110525226637
# Iteration 275: Best Cost = 1.6681110525226637
# Iteration 276: Best Cost = 1.6681110525226637
# Iteration 277: Best Cost = 1.6681110525226637
# Iteration 278: Best Cost = 1.6681110525226637
# Iteration 279: Best Cost = 1.6681110525226637
# Iteration 280: Best Cost = 1.6681110525226637
# Iteration 281: Best Cost = 1.6681110525226637
# Iteration 282: Best Cost = 1.6681110525226637
# Iteration 283: Best Cost = 1.6681110525226637
# Iteration 284: Best Cost = 1.6681110525226637
# Iteration 285: Best Cost = 1.6681110525226637
# Iteration 286: Best Cost = 1.6681110525226637
# Iteration 287: Best Cost = 1.6681110525226637
# Iteration 288: Best Cost = 1.6681110525226637
# Iteration 289: Best Cost = 1.6681110525226637
# Iteration 290: Best Cost = 1.6681110525226637
# Iteration 291: Best Cost = 1.6681110525226637
# Iteration 292: Best Cost = 1.6681110525226637
# Iteration 293: Best Cost = 1.6681110525226637
# Iteration 294: Best Cost = 1.6681110525226637
# Iteration 295: Best Cost = 1.6681110525226637
# Iteration 296: Best Cost = 1.6681110525226637
# Iteration 297: Best Cost = 1.6681110525226637
# Iteration 298: Best Cost = 1.6681110525226637
# Iteration 299: Best Cost = 1.6681110525226637
# Iteration 300: Best Cost = 1.6681110525226637
# Iteration 301: Best Cost = 1.6681110525226637
# Iteration 302: Best Cost = 1.6681110525226637
# Iteration 303: Best Cost = 1.6681110525226637
# Iteration 304: Best Cost = 1.6681110525226637
# Iteration 305: Best Cost = 1.6681110525226637
# Iteration 306: Best Cost = 1.6681110525226637
# Iteration 307: Best Cost = 1.6681110525226637
# Iteration 308: Best Cost = 1.6681110525226637
# Iteration 309: Best Cost = 1.6681110525226637
# Iteration 310: Best Cost = 1.6681110525226637
# Iteration 311: Best Cost = 1.6681110525226637
# Iteration 312: Best Cost = 1.6681110525226637
# Iteration 313: Best Cost = 1.610338113545696
# Iteration 314: Best Cost = 1.610338113545696
# Iteration 315: Best Cost = 1.610338113545696
# Iteration 316: Best Cost = 1.610338113545696
# Iteration 317: Best Cost = 1.610338113545696
# Iteration 318: Best Cost = 1.610338113545696
# Iteration 319: Best Cost = 1.610338113545696
# Iteration 320: Best Cost = 1.610338113545696
# Iteration 321: Best Cost = 1.610338113545696
# Iteration 322: Best Cost = 1.610338113545696
# Iteration 323: Best Cost = 1.610338113545696
# Iteration 324: Best Cost = 1.610338113545696
# Iteration 325: Best Cost = 1.610338113545696
# Iteration 326: Best Cost = 1.610338113545696
# Iteration 327: Best Cost = 1.610338113545696
# Iteration 328: Best Cost = 1.610338113545696
# Iteration 329: Best Cost = 1.610338113545696
# Iteration 330: Best Cost = 1.610338113545696
# Iteration 331: Best Cost = 1.610338113545696
# Iteration 332: Best Cost = 1.610338113545696
# Iteration 333: Best Cost = 1.610338113545696
# Iteration 334: Best Cost = 1.610338113545696
# Iteration 335: Best Cost = 1.610338113545696
# Iteration 336: Best Cost = 1.610338113545696
# Iteration 337: Best Cost = 1.610338113545696
# Iteration 338: Best Cost = 1.610338113545696
# Iteration 339: Best Cost = 1.610338113545696
# Iteration 340: Best Cost = 1.610338113545696
# Iteration 341: Best Cost = 1.610338113545696
# Iteration 342: Best Cost = 1.610338113545696
# Iteration 343: Best Cost = 1.610338113545696
# Iteration 344: Best Cost = 1.610338113545696
# Iteration 345: Best Cost = 1.610338113545696
# Iteration 346: Best Cost = 1.610338113545696
# Iteration 347: Best Cost = 1.610338113545696
# Iteration 348: Best Cost = 1.610338113545696
# Iteration 349: Best Cost = 1.610338113545696
# Iteration 350: Best Cost = 1.610338113545696
# Iteration 351: Best Cost = 1.610338113545696
# Iteration 352: Best Cost = 1.610338113545696
# Iteration 353: Best Cost = 1.610338113545696
# Iteration 354: Best Cost = 1.610338113545696
# Iteration 355: Best Cost = 1.610338113545696
# Iteration 356: Best Cost = 1.610338113545696
# Iteration 357: Best Cost = 1.610338113545696
# Iteration 358: Best Cost = 1.610338113545696
# Iteration 359: Best Cost = 1.610338113545696
# Iteration 360: Best Cost = 1.610338113545696
# Iteration 361: Best Cost = 1.610338113545696
# Iteration 362: Best Cost = 1.610338113545696
# Iteration 363: Best Cost = 1.610338113545696
# Iteration 364: Best Cost = 1.610338113545696
# Iteration 365: Best Cost = 1.610338113545696
# Iteration 366: Best Cost = 1.610338113545696
# Iteration 367: Best Cost = 1.610338113545696
# Iteration 368: Best Cost = 1.610338113545696
# Iteration 369: Best Cost = 1.610338113545696
# Iteration 370: Best Cost = 1.610338113545696
# Iteration 371: Best Cost = 1.610338113545696
# Iteration 372: Best Cost = 1.610338113545696
# Iteration 373: Best Cost = 1.610338113545696
# Iteration 374: Best Cost = 1.610338113545696
# Iteration 375: Best Cost = 1.610338113545696
# Iteration 376: Best Cost = 1.610338113545696
# Iteration 377: Best Cost = 1.610338113545696
# Iteration 378: Best Cost = 1.1401214653978038
# Iteration 379: Best Cost = 1.1401214653978038
# Iteration 380: Best Cost = 1.1401214653978038
# Iteration 381: Best Cost = 1.1401214653978038
# Iteration 382: Best Cost = 1.1401214653978038
# Iteration 383: Best Cost = 1.1401214653978038
# Iteration 384: Best Cost = 1.1401214653978038
# Iteration 385: Best Cost = 1.1401214653978038
# Iteration 386: Best Cost = 1.1401214653978038
# Iteration 387: Best Cost = 1.1401214653978038
# Iteration 388: Best Cost = 1.1401214653978038
# Iteration 389: Best Cost = 1.1401214653978038
# Iteration 390: Best Cost = 1.1401214653978038
# Iteration 391: Best Cost = 1.1401214653978038
# Iteration 392: Best Cost = 1.1401214653978038
# Iteration 393: Best Cost = 1.1401214653978038
# Iteration 394: Best Cost = 1.1401214653978038
# Iteration 395: Best Cost = 1.1401214653978038
# Iteration 396: Best Cost = 1.1401214653978038
# Iteration 397: Best Cost = 1.1401214653978038
# Iteration 398: Best Cost = 1.1401214653978038
# Iteration 399: Best Cost = 1.1401214653978038
# Iteration 400: Best Cost = 1.1401214653978038
# Iteration 401: Best Cost = 1.1401214653978038
# Iteration 402: Best Cost = 1.1401214653978038
# Iteration 403: Best Cost = 1.1401214653978038
# Iteration 404: Best Cost = 1.1401214653978038
# Iteration 405: Best Cost = 1.1401214653978038
# Iteration 406: Best Cost = 1.1401214653978038
# Iteration 407: Best Cost = 1.1401214653978038
# Iteration 408: Best Cost = 1.1401214653978038
# Iteration 409: Best Cost = 1.1401214653978038
# Iteration 410: Best Cost = 1.1401214653978038
# Iteration 411: Best Cost = 1.1401214653978038
# Iteration 412: Best Cost = 1.1401214653978038
# Iteration 413: Best Cost = 1.1401214653978038
# Iteration 414: Best Cost = 1.1401214653978038
# Iteration 415: Best Cost = 1.1401214653978038
# Iteration 416: Best Cost = 1.1401214653978038
# Iteration 417: Best Cost = 1.1401214653978038
# Iteration 418: Best Cost = 1.1401214653978038
# Iteration 419: Best Cost = 1.1401214653978038
# Iteration 420: Best Cost = 1.1401214653978038
# Iteration 421: Best Cost = 1.1401214653978038
# Iteration 422: Best Cost = 1.1401214653978038
# Iteration 423: Best Cost = 1.1401214653978038
# Iteration 424: Best Cost = 1.1401214653978038
# Iteration 425: Best Cost = 1.1401214653978038
# Iteration 426: Best Cost = 1.1401214653978038
# Iteration 427: Best Cost = 1.1401214653978038
# Iteration 428: Best Cost = 1.1401214653978038
# Iteration 429: Best Cost = 1.1401214653978038
# Iteration 430: Best Cost = 1.1401214653978038
# Iteration 431: Best Cost = 1.1401214653978038
# Iteration 432: Best Cost = 1.1401214653978038
# Iteration 433: Best Cost = 1.1401214653978038
# Iteration 434: Best Cost = 1.1401214653978038
# Iteration 435: Best Cost = 1.1401214653978038
# Iteration 436: Best Cost = 1.1401214653978038
# Iteration 437: Best Cost = 1.1401214653978038
# Iteration 438: Best Cost = 1.1401214653978038
# Iteration 439: Best Cost = 1.1401214653978038
# Iteration 440: Best Cost = 1.1401214653978038
# Iteration 441: Best Cost = 1.1401214653978038
# Iteration 442: Best Cost = 1.1401214653978038
# Iteration 443: Best Cost = 1.1401214653978038
# Iteration 444: Best Cost = 1.1401214653978038
# Iteration 445: Best Cost = 1.1401214653978038
# Iteration 446: Best Cost = 1.1401214653978038
# Iteration 447: Best Cost = 1.1401214653978038
# Iteration 448: Best Cost = 1.1401214653978038
# Iteration 449: Best Cost = 1.1401214653978038
# Iteration 450: Best Cost = 1.1401214653978038
# Iteration 451: Best Cost = 1.1401214653978038
# Iteration 452: Best Cost = 1.1401214653978038
# Iteration 453: Best Cost = 1.1401214653978038
# Iteration 454: Best Cost = 1.1401214653978038
# Iteration 455: Best Cost = 1.1401214653978038
# Iteration 456: Best Cost = 1.1401214653978038
# Iteration 457: Best Cost = 1.1401214653978038
# Iteration 458: Best Cost = 1.1401214653978038
# Iteration 459: Best Cost = 1.1401214653978038
# Iteration 460: Best Cost = 1.1401214653978038
# Iteration 461: Best Cost = 1.1401214653978038
# Iteration 462: Best Cost = 1.1401214653978038
# Iteration 463: Best Cost = 1.1401214653978038
# Iteration 464: Best Cost = 1.1401214653978038
# Iteration 465: Best Cost = 1.1401214653978038
# Iteration 466: Best Cost = 1.1401214653978038
# Iteration 467: Best Cost = 1.1401214653978038
# Iteration 468: Best Cost = 1.1401214653978038
# Iteration 469: Best Cost = 1.1401214653978038
# Iteration 470: Best Cost = 1.1401214653978038
# Iteration 471: Best Cost = 1.1401214653978038
# Iteration 472: Best Cost = 1.1401214653978038
# Iteration 473: Best Cost = 1.1401214653978038
# Iteration 474: Best Cost = 1.1401214653978038
# Iteration 475: Best Cost = 1.1401214653978038
# Iteration 476: Best Cost = 1.1401214653978038
# Iteration 477: Best Cost = 1.1401214653978038
# Iteration 478: Best Cost = 1.1401214653978038
# Iteration 479: Best Cost = 1.1401214653978038
# Iteration 480: Best Cost = 1.1401214653978038
# Iteration 481: Best Cost = 1.1401214653978038
# Iteration 482: Best Cost = 1.1401214653978038
# Iteration 483: Best Cost = 1.1401214653978038
# Iteration 484: Best Cost = 1.1401214653978038
# Iteration 485: Best Cost = 1.1401214653978038
# Iteration 486: Best Cost = 1.1401214653978038
# Iteration 487: Best Cost = 1.1401214653978038
# Iteration 488: Best Cost = 1.1401214653978038
# Iteration 489: Best Cost = 1.1401214653978038
# Iteration 490: Best Cost = 1.1401214653978038
# Iteration 491: Best Cost = 1.1401214653978038
# Iteration 492: Best Cost = 1.1401214653978038
# Iteration 493: Best Cost = 1.1401214653978038
# Iteration 494: Best Cost = 1.1401214653978038
# Iteration 495: Best Cost = 1.1401214653978038
# Iteration 496: Best Cost = 1.1401214653978038
# Iteration 497: Best Cost = 1.1401214653978038
# Iteration 498: Best Cost = 1.1401214653978038
# Iteration 499: Best Cost = 1.1401214653978038
# Iteration 500: Best Cost = 1.1401214653978038
# <function matplotlib.pyplot.show>
